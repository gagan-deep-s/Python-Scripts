# %%
import pandas as pd

# %%
# Data Extract
# Import data from website on (The 50 largest companies by revenue in 2021 according to the Fortune India 500)
data=pd.read_html('https://en.wikipedia.org/wiki/List_of_largest_companies_in_India#2022_Forbes_list',index_col=False)

# %%
# List top 5 data
data[1].head()
# Out:
#    Rank                             Name     Industry  Revenue (in ₹ Crore)  \
# 0     1           Indian Oil Corporation  Oil and gas                424321
# 1     2      Reliance Industries Limited  Oil and gas                410295
# 2     3  Oil and Natural Gas Corporation  Oil and gas                333143
# 3     4              State Bank of India      Banking                306528
# 4     5                      Tata Motors   Automotive                301175
#
#    Revenue growth Profits (in ₹ Crore) Headquarters State Controlled
# 0             NaN                22189    New Delhi              Yes
# 1             NaN                36075       Mumbai              NaN
# 2             NaN                22106    New Delhi              Yes
# 3             NaN               −4,556       Mumbai              Yes
# 4             NaN                 8989       Mumbai              NaN

# %%
# Assigning data to another data frame
top_comp=data[1]

# %%
#Performing data cleanup
top=top_comp.loc[:, top_comp.columns != 'Revenue growth']

# %%
# Replacing null data with character
top.fillna("Not Sure").head()
# Out:
#    Rank                             Name     Industry  Revenue (in ₹ Crore)  \
# 0     1           Indian Oil Corporation  Oil and gas                424321
# 1     2      Reliance Industries Limited  Oil and gas                410295
# 2     3  Oil and Natural Gas Corporation  Oil and gas                333143
# 3     4              State Bank of India      Banking                306528
# 4     5                      Tata Motors   Automotive                301175
#
#   Profits (in ₹ Crore) Headquarters State Controlled
# 0                22189    New Delhi              Yes
# 1                36075       Mumbai         Not Sure
# 2                22106    New Delhi              Yes
# 3               −4,556       Mumbai              Yes
# 4                 8989       Mumbai         Not Sure

# %%
# Replace index with Rank column
top.set_index('Rank',inplace=True)

# %%
top.groupby('Name').mean()
# Out:
# C:\Users\GAGAN DEEP\AppData\Local\Temp\ipykernel_28044\3682057533.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top.groupby('Name').mean()
#                                         Revenue (in ₹ Crore)
# Name
# Axis Bank                                            58477.0
# Bajaj Finserv                                        30599.0
# Bank of Baroda                                       54048.0
# Bank of India                                        44158.0
# Bharat Petroleum                                    238638.0
# Bharti Airtel                                        86704.0
# Canara Bank                                          48743.0
# Chennai Petroleum Corporation                        33187.0
# Coal India                                          132897.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(top.loc[:,'Revenue (in ₹ Crore)'].head(10),labels=top.loc[:,'Name'].head(10))

plt.show()

# %%
plt.barh(top.loc[:,'Name'].head(10),top.loc[:,'Revenue (in ₹ Crore)'].head(10))
plt.show()
